# %%
import pandas as pd

file = pd.read_csv('study.csv')

# %%
file.head()

# %%
num_rows, num_columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 num_rows
#
# NameError: name 'num_rows' is not defined

# %%
file = file.drop_duplicates(subset='gender', keep='first')
file

# %%
apagitu = file.shape[0]
apagitu

# %%
bariskosong=file[file.isnull().any(axis=1)]
bariskosong

# %%
bariskosong=file.columns[file.isnull().any()]
bariskosong

# %%
databesar=file.isnull().sum().idxmax()
print(f"{databesar}")

datahilang=file[databesar].isnull().sum()
print(f"{datahilang}")

komposisi=file[databesar].value_counts(dropna=False)
komposisi

# %%
file_copy=file.copy()

file_copy.drop(columns=['age'])

# %%
filter=file[file.isnull().any(axis=1)]
print(len(filter))
filter.head()

# %%
hilangkan=file.dropna()
hilangkan

# %%
hilangkan.to_csv('databaru.xlsx', index=False)
