# %%
from tkinter import *
from PIL import Image,ImageTk

# %%
root = Tk()

mylabel = Label(root, text="woi bayar hutang lo").grid(row=10, column=5)
mylabel2 = Label(root, text="Males wlee").grid(row=5, column=10)

root.mainloop()

# %%
root = Tk()

def arh():
    Label(root, text="wlee", fg="yellow").pack()
        
Button(root, text="MALAS",padx=100, pady=50, command=arh, fg="white", bg="#000000").pack()


root.mainloop()

# use button() to use button
# use fg for font color, and bg for bacgkround color and specify the color, you can use the color name, or you can use the hex code
# use padx and pady to edit the uh button, but you can use it on anything
# use .pack(), .grid(), .place() to show the widget

# %%
root = Tk()

def arh():
    pentol=Label(root, text="namamu adalah.... " + a.get()).pack()
        

Label(root, text="prediksi nama").pack()

a=Entry(root)
a.pack()
a.insert(0, "Masukin namamu disini")

Button(root, text="Prediksi",padx=50, pady=20, command=arh).pack()

root.mainloop()

# use entry to input something idk
# use widht to width
# use border to border idk bro
# when using entry dont put the geometry manager one the same widget bro, pisah mereka pake variable biar nilai input user bisa dipake di .get()
# u can combine string and .get using the + broh i forgot tis thing exist
# use insert to insert some text in the entry box, but it count as a string so you need to delete them if you want to tnter something

# %%
root = Tk()

root.title("MANBAT")
root.iconbitmap('/home/akyr/Downloads/brave/batman.png')

root.mainloop()

# use iconbitmap to change the default logo of tkinter (but idk whats wrong with this, im using linux rn)

# %%
root = Tk()

Button(root, text="quit", command=root.quit).pack()

root.mainloop()

# use the .quit to uh.. quit

# %%
root = Tk()

a=ImageTk.PhotoImage(Image.open("batman.png"))
Label(image=a).pack()

root.mainloop()

# fungsinya munculin gambar, cara kerjanya dengan mengconvert image ke PhotoImage (hal yang dikenali sama python) lalu gambarnya disimpan di label

# %%
root = Tk()

p = ["aku","kau","kulo","hai","saijda", ]

status = Label(root, text="how many " + str(len(p))).pack()

root.mainloop()

# yea you can use list and len to do something like this, not just string tho, image, int, ow anything idk
